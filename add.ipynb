# %%
import pandas as pd
data=pd.read_csv('add.csv')
data
# Out:
#          x       y     sum
# 0      1.0     1.0     2.0
# 1      4.0     4.0     8.0
# 2      6.0     6.0    12.0
# 3     10.0    10.0    20.0
# 4     30.0    30.0    60.0
# 5     23.0    43.0    66.0
# 6     55.0    80.0   135.0
# 7    100.0    22.0   122.0
# 8     23.0    45.0    68.0
# 9     56.0    78.0   134.0
# 10    13.0    78.0    91.0
# 11   300.0    34.0   334.0
# 12    12.5    56.7    69.2
# 13    23.6    89.3   112.9
# 14    67.8    87.9   155.7
# 15   200.0   700.0   900.0
# 16   203.6    67.9   271.5
# 17   400.0    45.7   445.7
# 18    34.6    56.9    91.5
# 19   400.5   356.0   756.5
# 20    45.7   123.7   169.4
# 21  1000.0  3456.0  4456.0

# %%
import matplotlib.pyplot as mt
mt.scatter(data['x'],data['sum'])

# %%
mt.scatter(data['y'],data['sum'])

# %%
mt.scatter(data['x'],data['y'])

# %% [markdown]
# 1. Store Feature matrix in X and response (Target) in vector y

# %%
X=data[['x','y']]
y=data['sum']

X
# Out:
#          x       y
# 0      1.0     1.0
# 1      4.0     4.0
# 2      6.0     6.0
# 3     10.0    10.0
# 4     30.0    30.0
# 5     23.0    43.0
# 6     55.0    80.0
# 7    100.0    22.0
# 8     23.0    45.0
# 9     56.0    78.0
# 10    13.0    78.0
# 11   300.0    34.0
# 12    12.5    56.7
# 13    23.6    89.3
# 14    67.8    87.9
# 15   200.0   700.0
# 16   203.6    67.9
# 17   400.0    45.7
# 18    34.6    56.9
# 19   400.5   356.0
# 20    45.7   123.7
# 21  1000.0  3456.0

# %% [markdown]
# TRAIN/TEST SPLIT [in sklearn]
# 1. split data into 2 parts: a training set and a testing set
# 2. train the model on training set
# 3. test the model on testing set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(
X,y,test_size=0.33,random_state=8)
X_train
# Out:
#          x       y
# 2      6.0     6.0
# 18    34.6    56.9
# 15   200.0   700.0
# 1      4.0     4.0
# 19   400.5   356.0
# 0      1.0     1.0
# 16   203.6    67.9
# 21  1000.0  3456.0
# 8     23.0    45.0
# 5     23.0    43.0
# 9     56.0    78.0
# 17   400.0    45.7
# 20    45.7   123.7
# 3     10.0    10.0

# %% [markdown]
# Import & train the model

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Check Model's Prediction Performance

# %%
model.score(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 1.0

# %% [markdown]
# Comparing the Results

# %%
y_pred = model.predict(X_test)
y_pred
df=pd.DataFrame({'Actual':y_test,'prediction':y_pred})
df
# Out:
#     Actual  prediction
# 6    135.0       135.0
# 7    122.0       122.0
# 4     60.0        60.0
# 11   334.0       334.0
# 13   112.9       112.9
# 12    69.2        69.2
# 14   155.7       155.7
# 10    91.0        91.0

# %%
model.predict([[10,20]])
model.predict([[100.2,210.3]])
# Out:
# c:\ANACONDA\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# c:\ANACONDA\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([310.5])

# %% [markdown]
# linear regression is used to predict the relationship between 2 variables by applying a linear equation to observe data. there are 2 types of variables: one variable is called as an independent variable (x and y) and other is dependent variable (sum). linear regression is commonly used for predictive analysis. the main idea of regression is examing 2 things: first, does a set of predictive variables do a good job in prdeicting an output i.e dependent variable? second thing is which variables are significance predictor of the outcome variable. for example, a weight of person is linear related to the height so this shows a linear relationship between the height and weight of the person.
# we have 2 types of linear regression: single linear regression and multiple linear regerssion.
#
#
# # linear regression object will be created with the linear regression method if u wnat to call the fit method to train the model
# # we need the object of linear regression class
# # fit method having 2 parameters -> vector and feature matrices
# # vector is holding the dependent variant and feature matrix hold the independent variant
