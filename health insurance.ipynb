# %%
import pandas as pd 

data=pd.read_csv('insurance.csv')
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# # 1. Display Top 5 Rows of The Dataset

# %%
data.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # 2. Check Last 5 Rows of The Dataset

# %%
data.tail(5)
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %% [markdown]
# # 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
data.shape
# Out:
# (1338, 7)

# %% [markdown]
# # 4. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# # 5.Check Null Values In The Dataset

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# # 6. Get Overall Statistics About The Dataset

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# # 7. Covert Columns From String ['sex' ,'smoker','region' ] To Numerical Values

# %%
data["sex"] = data["sex"].replace({"male":0,"female":1})
data["smoker"] = data["smoker"].replace({"no":0,"yes":1})
data["region"] = data["region"].replace({"southwest":0,"southeast":1,"northwest":2,"northeast":3})
data
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_246184\1974170214.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data["sex"] = data["sex"].replace({"male":0,"female":1})
# C:\Users\Dell\AppData\Local\Temp\ipykernel_246184\1974170214.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data["smoker"] = data["smoker"].replace({"no":0,"yes":1})
# ...

# %% [markdown]
# # 8. Store Feature Matrix In X and Response(Target) In Vector y

# %%
X = data[["age","sex","bmi","children","smoker","region"]]
y = data["charges"]
X
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    1  27.900         0       1       0
# 1      18    0  33.770         1       0       1
# 2      28    0  33.000         3       0       1
# 3      33    0  22.705         0       0       2
# 4      32    0  28.880         0       0       2
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    0  30.970         3       0       2
# 1334   18    1  31.920         0       0       3
# 1335   18    1  36.850         0       0       1
# 1336   21    1  25.800         0       0       0
# 1337   61    1  29.070         0       1       2
#
# [1338 rows x 6 columns]

# %% [markdown]
# # 9. Train/Test split¶
# 1. Split data into two part : a training set and a testing set
# 2. Train the model(s) on training set
# 3. Test the Model(s) on Testing set#

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train
# Out:
#       age  sex     bmi  children  smoker  region
# 621    37    0  34.100         4       1       0
# 194    18    0  34.430         0       0       1
# 240    23    1  36.670         2       1       3
# 1168   32    0  35.200         2       0       0
# 1192   58    1  32.395         1       0       3
# ...   ...  ...     ...       ...     ...     ...
# 763    27    0  26.030         0       0       3
# 835    42    0  35.970         2       0       1
# 1216   40    0  25.080         0       0       1
# 559    19    0  35.530         0       0       2
# 684    33    1  18.500         1       0       0
#
# [1070 rows x 6 columns]

# %% [markdown]
# # 10. Import the models

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # 11. Model Training

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # 12. Prediction on Test Data

# %%
model.score(X_train,y_train)
# Out:
# 0.7368306228430945

# %% [markdown]
# # 13. Compare Performance Visually

# %%
y_pred = model.predict(X_test)
data2 = pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
data2
# Out:
#            Actual     Predicted
# 578    9724.53000  11017.230479
# 610    8547.69130   9787.530168
# 569   45702.02235  37994.782118
# 1034  12950.07120  16122.778407
# 198    9644.25250   6930.759230
# ...           ...           ...
# 1084  15019.76005  14699.098767
# 726    6664.68595   8210.854549
# 1132  20709.02034  16019.284542
# 725   40932.42950  33104.944084
# 963    9500.57305   9471.247528
#
# [268 rows x 2 columns]

# %% [markdown]
# # 14. Predict Charges For New Customer

# %%
model.predict([[37,0,34.1,4,1,0,],[32,0,35.200,2,0,0]])
# Out:
# c:\ANACONDA\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([33388.19026849,  8023.13581024])

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train,y_train)
# Out:
# 0.7368306228430945

# %%
from sklearn.svm import SVR
svm = SVR()
svm.fit(X_train,y_train)
# Out:
# SVR()

# %%
svm.score(X_train,y_train)
# Out:
# -0.09749145150086735

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf.score(X_train,y_train)
# Out:
# 0.9746128981215432

# %%
from sklearn.ensemble import GradientBoostingRegressor
gr = GradientBoostingRegressor()
gr.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
gr.score(X_train,y_train)
# Out:
# 0.897352642499688

# %%
# Assuming data2 is the DataFrame containing "Actual" and "Predicted" columns

import matplotlib.pyplot as plt
plt.subplot(221)
plt.plot(data2['Actual'].iloc[0:11],label='Actual')
plt.plot(data2['Predicted'].iloc[0:11],label="Predicted")
plt.legend()

# %%
y_pred = svm.predict(X_test)
data2 = pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
data2
# Out:
#            Actual    Predicted
# 578    9724.53000  9470.622693
# 610    8547.69130  9438.795091
# 569   45702.02235  9448.255011
# 1034  12950.07120  9515.556242
# 198    9644.25250  9455.922366
# ...           ...          ...
# 1084  15019.76005  9519.869305
# 726    6664.68595  9398.173374
# 1132  20709.02034  9497.677876
# 725   40932.42950  9337.806392
# 963    9500.57305  9430.123646
#
# [268 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.subplot(221)
plt.plot(data2['Actual'].iloc[0:11],label='Actual')
plt.plot(data2['Predicted'].iloc[0:11],label="Predicted")
plt.legend()

# %%
y_pred = rf.predict(X_test)
data2 = pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
data2
# Out:
#            Actual     Predicted
# 578    9724.53000  11586.535159
# 610    8547.69130  10136.483202
# 569   45702.02235  44283.779962
# 1034  12950.07120  13037.163493
# 198    9644.25250  10585.905659
# ...           ...           ...
# 1084  15019.76005  15589.929104
# 726    6664.68595   6709.579133
# 1132  20709.02034  11618.026230
# 725   40932.42950  43517.636068
# 963    9500.57305   9362.310459
#
# [268 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.subplot(221)
plt.plot(data2['Actual'].iloc[0:11],label='Actual')
plt.plot(data2['Predicted'].iloc[0:11],label="Predicted")
plt.legend()

# %%
y_pred = gr.predict(X_test)
data2 = pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
data2
# Out:
#            Actual     Predicted
# 578    9724.53000  12141.827923
# 610    8547.69130   9538.762935
# 569   45702.02235  45616.085830
# 1034  12950.07120  14329.307907
# 198    9644.25250  10330.394823
# ...           ...           ...
# 1084  15019.76005  17325.503462
# 726    6664.68595   7417.494837
# 1132  20709.02034  11753.443070
# 725   40932.42950  40485.731999
# 963    9500.57305   9888.243228
#
# [268 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.subplot(221)
plt.plot(data2['Actual'].iloc[0:11],label='Actual')
plt.plot(data2['Predicted'].iloc[0:11],label="Predicted")
plt.legend()
